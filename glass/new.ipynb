# %%
import pandas as pd

# %%
book = pd.read_csv("log.txt", sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
# Out:
# /tmp/ipykernel_425/837786806.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   book = pd.read_csv("log.txt", sep=',', error_bad_lines=False, index_col=False, dtype='unicode')

# %%
book
# Out:
#           sec  count   bid or ask  0 prise      0 size  1 prise      1 size  \
# 0       1.719       0         ASK    8.464       50000    8.465      180000
# 1       1.719       0         BID     8.46       50000    8.459      400000
# 2       5.471       1         ASK    8.464       50000    8.465      180000
# 3       5.471       1         BID     8.46       50000    8.459      400000
# 4       5.471       2         ASK    8.464       50000    8.465      180000
# ...       ...     ...         ...      ...         ...      ...         ...
# 72435  38.112   36217         BID    8.479   174360000    8.478   163721000
# 72436  39.661   36218         ASK    8.404     1034000    8.405     3213000
# 72437  39.661   36218         BID    8.479   174360000    8.478   163721000
# 72438  40.108   36219         ASK    8.404     1034000    8.405     3213000
# 72439  40.108   36219         BID    8.479   174360000    8.478   163721000
#
# ...
